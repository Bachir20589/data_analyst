# %%
import pandas as p
dataset={
    "nom":["Ali","Modou","Moussa"],
    "age":[20,21,18]
}
a=p.DataFrame(dataset)
print(a.head(2))
print(a.loc[[0,1]])
b=[0,"ma",30]
c=p.Series(b,index=["a","b","c"])
print(c)
# Out:
#      nom  age
# 0    Ali   20
# 1  Modou   21
#      nom  age
# 0    Ali   20
# 1  Modou   21
# a     0
# b    ma
# c    30
# dtype: object
