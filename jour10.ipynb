# %%
import pandas as p

data={
    "duree":{
        "0":8,
        "1":10
    },
    "pause":{
        "0":12,
        "1":13
    }
}

f=p.DataFrame(data)
print(f.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   duree   2 non-null      int64
#  1   pause   2 non-null      int64
# dtypes: int64(2)
# memory usage: 48.0+ bytes
# None
