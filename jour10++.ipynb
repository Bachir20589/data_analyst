# %%
import pandas as p

f=p.read_csv("jour10.csv")
print(f)
a=f.groupby("nom")["age"].mean()
print(a)
# Out:
#      nom  age
# 0  Modou   20
# 1    Ali   14
# nom
# Ali      14.0
# Modou    20.0
# Name: age, dtype: float64
