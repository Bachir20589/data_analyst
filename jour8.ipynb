# %%
import pandas as p
f=p.read_csv("etudiant.csv")
print(f.to_string())
m=f["age"].mean()
a=f.groupby("filiere")["age"].mean()
n=f[f["filiere"]=="ING1"]
b=f["age"].value_counts()
print(m)
print(a)
print(n)
print(b)
# Out:
#      nom  age filiere
# 0  Modou   20    ING1
# 1    Ali   21    ING3
# 2  Fatou   19    ING1
# 3    Awa   21    ING1
# 20.25
# filiere
# ING1    20.0
# ING3    21.0
# Name: age, dtype: float64
#      nom  age filiere
# 0  Modou   20    ING1
# 2  Fatou   19    ING1
# 3    Awa   21    ING1
# age
# 21    2
# 20    1
# 19    1
# Name: count, dtype: int64

# %%
# import pandas as p
firstdataset={
    "name":["Modou","Ali","Abdou","Awa","Fatou","Moussa","Ada"],
    "age":[20,39,21,19,34,14,17]
}

m=p.DataFrame(firstdataset)
print(m.to_string())
print(m.head())
print(m.tail())
for i in m.itertuples():
    print(i.name + " " + str(i.age) + " " + "ans")
print(p.__version__)
my= [1,9,0]
e=p.Series(my,index=["x","y","z"])
print(e)
# Out:
#      name  age
# 0   Modou   20
# 1     Ali   39
# 2   Abdou   21
# 3     Awa   19
# 4   Fatou   34
# 5  Moussa   14
# 6     Ada   17
#     name  age
# 0  Modou   20
# 1    Ali   39
# 2  Abdou   21
# 3    Awa   19
# 4  Fatou   34
#      name  age
# 2   Abdou   21
# 3     Awa   19
# 4   Fatou   34
# 5  Moussa   14
# 6     Ada   17
# Modou 20 ans
# Ali 39 ans
# Abdou 21 ans
# Awa 19 ans
# Fatou 34 ans
# Moussa 14 ans
# Ada 17 ans
# 3.0.5
# x    1
# y    9
# z    0
# dtype: int64
