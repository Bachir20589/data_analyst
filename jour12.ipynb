# %%
import pandas as p
with open("etudiant1.csv") as f:
    a=p.read_csv(f)
    b=a.dropna(inplace=True)
    # c=a.fillna({"nom":"Modou","poids":45,"age":10},inplace=True)
    # d=p.to_datetime(a['date'],format='mixed')
    # r=a.dropna(subset=['date'],inplace=True)
for x in a.index:
    if a.loc[x,"age"]>18:
        a.loc[x,"age"]=20

print(a)
# Out:
#       nom filiere   age  poids          date
# 1  Bachir    Ing3  20.0   43.0  '2020-05-09'
