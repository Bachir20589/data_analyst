# %%
import pandas as pd


p=pd.read_csv("etudiant.csv")
print(p)
p["age"].mean()
p.head(2)
# Out:
#      nom  age filiere
# 0  Modou   20    ING1
# 1    Ali   21    ING3
# 2  Fatou   19    ING1
# 3    Awa   21    ING1
#      nom  age filiere
# 0  Modou   20    ING1
# 1    Ali   21    ING3

# %%
print(p["age"].mean())
print(p[p["filiere"]=="ING1"])
print(p.groupby("filiere")["age"].mean())
p["filiere"].value_counts()
# Out:
# 20.25
#      nom  age filiere
# 0  Modou   20    ING1
# 2  Fatou   19    ING1
# 3    Awa   21    ING1
# filiere
# ING1    20.0
# ING3    21.0
# Name: age, dtype: float64
# filiere
# ING1    3
# ING3    1
# Name: count, dtype: int64
